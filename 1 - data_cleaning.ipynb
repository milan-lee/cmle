# %%
##%%bash
##mkdir data

# %%
#!gsutil cp gs://airbnb_datasets/google_pilot_fi_dataset_01_scaled_with_holdout.csv data/
# Out:
# Copying gs://airbnb_datasets/google_pilot_fi_dataset_01_scaled_with_holdout.csv...
# / [0 files][  2.6 GiB/  5.3 GiB]   69.7 MiB/s

# %%
import pandas as pd
df = pd.read_csv("./data/google_pilot_fi_dataset_01_scaled_with_holdout.csv")

# %%
df.shape
# Out:
# (2316554, 176)

# %%
df.head(25)
# Out:
#                          id_listing_anon  \
# 0   dd41249c-9b94-4cca-a8ed-1a402a27b139
# 1   4f4d8f98-8e7e-444b-ac9d-66a7892d1f10
# 2   53f64d7d-6e8a-4818-b85d-45e9bd72c952
# 3   d3e1972a-5d73-4fc4-90fb-c2dc4eb0c4cd
# 4   371747fe-adc2-4268-a37d-07e02d14e182
# 5   9adb5aa5-6a1e-4ffe-b9c9-2685158d4aad
# 6   f6662a75-f1b1-4791-a60b-01ede91c8b5a
# 7   d0510471-b110-4300-a747-9d591e653348
# 8   a54ee4f3-dfdf-4bfc-8716-46991e1746b5
# 9   c3596048-eea7-4cdb-949c-ed052787476a
# 10  fdfecd84-90d9-4abe-8e3b-2de6240225fd
# 11  08ee3267-43db-48ad-a301-d2e47aaf4dfa
# 12  c0b2b354-3b1d-40b9-a971-972a19173dee
# 13  68c708f3-07e9-4ce6-9776-38fc0ecc7e81
# 14  237a60d1-12d5-474a-a8cd-280b87935ef9
# 15  911fee96-3ae3-4284-ad20-b5fcfdbc9e48
# 16  c1125886-2b9d-421d-b821-920b6c5abb08
# 17  d90f6b9f-c874-4caf-b4bf-fd02af729687
# 18  8e8332f2-6bd3-40ae-8c3e-ceae3faafe13
# 19  fdb88c92-bf21-4bdd-8473-11c481b7d585
# 20  eda61819-d669-4e08-be3a-b27c66069b5d
# 21  e4751a07-f126-4a3f-bb37-980058887a94
# ...

# %%
df['is_fi'].isnull().sum()
# Out:
# 682720

# %%
df_test = df[df['is_fi'].isnull()]

# %%
df_test.shape
# Out:
# (682720, 176)

# %%
df_train = df[pd.notnull(df['is_fi'])]

# %%
df_train.shape
# Out:
# (1633834, 176)

# %%
#2316554
1633834 + 682720
# Out:
# 2316554

# %%
df_train.head(20)
# Out:
#                          id_listing_anon  \
# 3   d3e1972a-5d73-4fc4-90fb-c2dc4eb0c4cd
# 4   371747fe-adc2-4268-a37d-07e02d14e182
# 7   d0510471-b110-4300-a747-9d591e653348
# 8   a54ee4f3-dfdf-4bfc-8716-46991e1746b5
# 10  fdfecd84-90d9-4abe-8e3b-2de6240225fd
# 11  08ee3267-43db-48ad-a301-d2e47aaf4dfa
# 12  c0b2b354-3b1d-40b9-a971-972a19173dee
# 13  68c708f3-07e9-4ce6-9776-38fc0ecc7e81
# 14  237a60d1-12d5-474a-a8cd-280b87935ef9
# 18  8e8332f2-6bd3-40ae-8c3e-ceae3faafe13
# 19  fdb88c92-bf21-4bdd-8473-11c481b7d585
# 22  6b18080c-22eb-4288-98df-e4ce61865a7d
# 23  d7bec0e3-0bfd-4677-8aeb-8f00ae09059e
# 24  ee5b67e8-898c-4769-a069-4e413a07c1e2
# 25  26247fc2-87cf-4777-aa35-64320cbcf739
# 26  82b076d5-09e1-4717-a453-dc97cf5f9457
# 27  06062d42-46f8-4d39-9920-b9414553a0ba
# 30  55f13e27-d187-46e5-bdeb-d75f17b907e0
# 36  4285657b-3efe-48e0-8508-29b3a162d8dc
# 38  b2d7ef86-ca07-4ca6-8ac4-7db1bb1d6b19
#
#                             id_user_anon     trigger_event  \
# ...

# %%
df_train.describe
# Out:
# <bound method DataFrame.describe of                               id_listing_anon  \
# 3        d3e1972a-5d73-4fc4-90fb-c2dc4eb0c4cd
# 4        371747fe-adc2-4268-a37d-07e02d14e182
# 7        d0510471-b110-4300-a747-9d591e653348
# 8        a54ee4f3-dfdf-4bfc-8716-46991e1746b5
# 10       fdfecd84-90d9-4abe-8e3b-2de6240225fd
# 11       08ee3267-43db-48ad-a301-d2e47aaf4dfa
# 12       c0b2b354-3b1d-40b9-a971-972a19173dee
# 13       68c708f3-07e9-4ce6-9776-38fc0ecc7e81
# 14       237a60d1-12d5-474a-a8cd-280b87935ef9
# 18       8e8332f2-6bd3-40ae-8c3e-ceae3faafe13
# 19       fdb88c92-bf21-4bdd-8473-11c481b7d585
# 22       6b18080c-22eb-4288-98df-e4ce61865a7d
# 23       d7bec0e3-0bfd-4677-8aeb-8f00ae09059e
# 24       ee5b67e8-898c-4769-a069-4e413a07c1e2
# 25       26247fc2-87cf-4777-aa35-64320cbcf739
# 26       82b076d5-09e1-4717-a453-dc97cf5f9457
# 27       06062d42-46f8-4d39-9920-b9414553a0ba
# 30       55f13e27-d187-46e5-bdeb-d75f17b907e0
# 36       4285657b-3efe-48e0-8508-29b3a162d8dc
# ...

# %%
df_train_final = df_train.drop(columns=['id_listing_anon','id_user_anon','trigger_event','ts','fi_type'])

# %%
df_train_final["is_fi"] = df_train_final["is_fi"].astype('category',copy=False)

# %%
import numpy as np
df_train_final['is_fi_2'] = np.where(df_train_final['is_fi']==1.0, 'yes','no')

# %%
df_train_final.shape
# Out:
# (1633834, 172)

# %%
df_train_final['is_fi'].value_counts()
# Out:
# 0.0    1559432
# 1.0      74402
# Name: is_fi, dtype: int64

# %%
df_train_final['is_fi_2'].value_counts()
# Out:
# no     1559432
# yes      74402
# Name: is_fi_2, dtype: int64

# %%
df_train_final["is_fi"]
# Out:
# 3          0.0
# 4          0.0
# 7          0.0
# 8          0.0
# 10         0.0
# 11         0.0
# 12         0.0
# 13         0.0
# 14         0.0
# 18         0.0
# 19         0.0
# 22         1.0
# 23         0.0
# 24         0.0
# 25         0.0
# 26         0.0
# 27         0.0
# 30         0.0
# 36         0.0
# 38         0.0
# 40         0.0
# 41         0.0
# 42         0.0
# 43         0.0
# 44         0.0
# 46         0.0
# 47         0.0
# 48         0.0
# 49         0.0
# 50         0.0
#           ...
# 2316516    0.0
# 2316517    0.0
# 2316518    0.0
# 2316519    0.0
# 2316520    0.0
# 2316521    0.0
# 2316522    0.0
# 2316524    0.0
# 2316525    0.0
# 2316528    0.0
# 2316530    0.0
# 2316531    0.0
# 2316532    0.0
# 2316533    0.0
# 2316535    0.0
# 2316537    1.0
# 2316538    0.0
# 2316539    0.0
# 2316540    0.0
# 2316542    0.0
# 2316543    0.0
# 2316544    0.0
# 2316545    1.0
# 2316546    0.0
# 2316547    0.0
# 2316548    0.0
# 2316549    0.0
# ...

# %%
df_train_final["is_fi_2"]
# Out:
# 3           no
# 4           no
# 7           no
# 8           no
# 10          no
# 11          no
# 12          no
# 13          no
# 14          no
# 18          no
# 19          no
# 22         yes
# 23          no
# 24          no
# 25          no
# 26          no
# 27          no
# 30          no
# 36          no
# 38          no
# 40          no
# 41          no
# 42          no
# 43          no
# 44          no
# 46          no
# 47          no
# 48          no
# 49          no
# 50          no
#           ...
# 2316516     no
# 2316517     no
# 2316518     no
# 2316519     no
# 2316520     no
# 2316521     no
# 2316522     no
# 2316524     no
# 2316525     no
# 2316528     no
# 2316530     no
# 2316531     no
# 2316532     no
# 2316533     no
# 2316535     no
# 2316537    yes
# 2316538     no
# 2316539     no
# 2316540     no
# 2316542     no
# 2316543     no
# 2316544     no
# 2316545    yes
# 2316546     no
# 2316547     no
# 2316548     no
# 2316549     no
# ...

# %%
df_train_final.head(100)
# Out:
#     is_fi  anon_feature_001  anon_feature_002  anon_feature_003  \
# 3     0.0               NaN               NaN               NaN
# 4     0.0               NaN               NaN               NaN
# 7     0.0               NaN               NaN               NaN
# 8     0.0               NaN               NaN               NaN
# 10    0.0               NaN               NaN               NaN
# 11    0.0               NaN               NaN               NaN
# 12    0.0               NaN               NaN               NaN
# 13    0.0               NaN               NaN               NaN
# 14    0.0               NaN               NaN               NaN
# 18    0.0               NaN               NaN               NaN
# 19    0.0               NaN               NaN               NaN
# 22    1.0               NaN               NaN               NaN
# 23    0.0               NaN               NaN               NaN
# 24    0.0               NaN               NaN               NaN
# ...

# %%
df_train_final.to_csv('./data/train.csv',index=False)

# %%
# %%bash
# head -n 5 ./data/train.csv
# Out:
# is_fi,anon_feature_001,anon_feature_002,anon_feature_003,anon_feature_004,anon_feature_005,anon_feature_006,anon_feature_007,anon_feature_008,anon_feature_009,anon_feature_010,anon_feature_011,anon_feature_012,anon_feature_013,anon_feature_014,anon_feature_015,anon_feature_016,anon_feature_017,anon_feature_018,anon_feature_019,anon_feature_020,anon_feature_021,anon_feature_022,anon_feature_023,anon_feature_024,anon_feature_025,anon_feature_026,anon_feature_027,anon_feature_028,anon_feature_029,anon_feature_030,anon_feature_031,anon_feature_032,anon_feature_033,anon_feature_034,anon_feature_035,anon_feature_036,anon_feature_037,anon_feature_038,anon_feature_039,anon_feature_040,anon_feature_041,anon_feature_042,anon_feature_043,anon_feature_044,anon_feature_045,anon_feature_046,anon_feature_047,anon_feature_048,anon_feature_049,anon_feature_050,anon_feature_051,anon_feature_052,anon_feature_053,anon_feature_054,anon_feature_055,anon_feature_056,anon_feature_057,anon_feature_058,anon_f
# ...

# %%
# !gsutil -m cp ./data/train.csv gs://airbnb_datasets
# Out:
# Copying file://./data/train.csv [Content-Type=text/csv]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# - [1/1 files][  3.0 GiB/  3.0 GiB] 100% Done  48.2 MiB/s ETA 00:00:00
# Operation completed over 1 objects/3.0 GiB.

# %%
df_train_final.isnull().sum()
# Out:
# is_fi                     0
# anon_feature_001    1451364
# anon_feature_002    1451364
# anon_feature_003    1633834
# anon_feature_004    1451361
# anon_feature_005    1061927
# anon_feature_006    1061927
# anon_feature_007    1633834
# anon_feature_008    1060969
# anon_feature_009     876033
# anon_feature_010     876033
# anon_feature_011    1633834
# anon_feature_012     617731
# anon_feature_013     617731
# anon_feature_014    1633834
# anon_feature_015     617247
# anon_feature_016     491727
# anon_feature_017     491727
# anon_feature_018    1633834
# anon_feature_019     488940
# anon_feature_020    1506834
# anon_feature_021    1506834
# anon_feature_022    1506831
# anon_feature_023    1506831
# anon_feature_024    1535536
# anon_feature_025    1535536
# anon_feature_026    1535372
# anon_feature_027    1234243
# anon_feature_028    1234243
# anon_feature_029    1233981
#                      ...
# anon_feature_141    1559027
# anon_feature_142     558464
# ...

# %%
df_test.index.name = 'index_id'

# %%
df_test.head(10)
# Out:
#                                id_listing_anon  \
# index_id
# 0         dd41249c-9b94-4cca-a8ed-1a402a27b139
# 1         4f4d8f98-8e7e-444b-ac9d-66a7892d1f10
# 2         53f64d7d-6e8a-4818-b85d-45e9bd72c952
# 5         9adb5aa5-6a1e-4ffe-b9c9-2685158d4aad
# 6         f6662a75-f1b1-4791-a60b-01ede91c8b5a
# 9         c3596048-eea7-4cdb-949c-ed052787476a
# 15        911fee96-3ae3-4284-ad20-b5fcfdbc9e48
# 16        c1125886-2b9d-421d-b821-920b6c5abb08
# 17        d90f6b9f-c874-4caf-b4bf-fd02af729687
# 20        eda61819-d669-4e08-be3a-b27c66069b5d
#
#                                   id_user_anon     trigger_event  \
# index_id
# 0         efddaabb-9a41-4cf1-b551-168a2d272198    hosting_update
# 1         7beba309-b7a9-4d06-b898-67a02c9042da  hosting_activate
# 2         5eea3e17-7496-4018-b3c3-4b38f8b160e8    hosting_update
# 5         d7ecffe3-ec4f-420d-90e2-eefe4360736e    hosting_update
# 6         68cce11c-57d1-4f5b-ac74-b361455c68e8    hosting_update
# ...

# %%
df_test_final = df_test.drop(columns=['id_listing_anon','id_user_anon','trigger_event','ts','fi_type'
                                      ,"anon_feature_003"
                                        ,"anon_feature_007"
                                        ,"anon_feature_011"
                                        ,"anon_feature_014"
                                        ,"anon_feature_018"
                                        ,"anon_feature_033"
                                        ,"anon_feature_037"
                                        ,"anon_feature_045"
                                        ,"anon_feature_049"
                                        ,"anon_feature_053"
                                        ,"anon_feature_057"
                                        ,"anon_feature_061"
                                        ,"anon_feature_065"
                                        ,"anon_feature_072"
                                        ,"anon_feature_073"
                                        ,"anon_feature_074"
                                        ,"anon_feature_075"
                                        ,"anon_feature_076"
                                        ,"anon_feature_077"
                                        ,"anon_feature_078"
                                        ,"anon_feature_079"
                                        ,"anon_feature_080"
                                        ,"anon_feature_081"
                                        ,"anon_feature_082"
                                        ,"anon_feature_083"
                                        ,"anon_feature_084"
                                     ,"is_fi"])

# %%
df_test_final.shape
# Out:
# (682720, 144)

# %%
df_test_final.head(10)
# Out:
#           anon_feature_001  anon_feature_002  anon_feature_004  \
# index_id
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# 2                      NaN               NaN               NaN
# 5                      NaN               NaN               NaN
# 6                      NaN               NaN               NaN
# 9                      NaN               NaN               NaN
# 15                     NaN               NaN               NaN
# 16                     NaN               NaN               NaN
# 17                     NaN               NaN               NaN
# 20                0.939859           0.41684         -0.453761
#
#           anon_feature_005  anon_feature_006  anon_feature_008  \
# index_id
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# ...

# %%
df_test_final.isnull().sum()
# Out:
# is_fi               682720
# anon_feature_001    572062
# anon_feature_002    572062
# anon_feature_003    682720
# anon_feature_004    572062
# anon_feature_005    469282
# anon_feature_006    469282
# anon_feature_007    682720
# anon_feature_008    469282
# anon_feature_009    376371
# anon_feature_010    376371
# anon_feature_011    682720
# anon_feature_012    197911
# anon_feature_013    197911
# anon_feature_014    682720
# anon_feature_015    197911
# anon_feature_016    157258
# anon_feature_017    157258
# anon_feature_018    682720
# anon_feature_019    157258
# anon_feature_020    609090
# anon_feature_021    609090
# anon_feature_022    609090
# anon_feature_023    609090
# anon_feature_024    636481
# anon_feature_025    636481
# anon_feature_026    636481
# anon_feature_027    489947
# anon_feature_028    489947
# anon_feature_029    489947
#                      ...
# anon_feature_141    650580
# anon_feature_142    174550
# anon_feature_143     53287
# ...

# %%
df_test.head(10)
# Out:
#                                id_listing_anon  \
# index_id
# 0         dd41249c-9b94-4cca-a8ed-1a402a27b139
# 1         4f4d8f98-8e7e-444b-ac9d-66a7892d1f10
# 2         53f64d7d-6e8a-4818-b85d-45e9bd72c952
# 5         9adb5aa5-6a1e-4ffe-b9c9-2685158d4aad
# 6         f6662a75-f1b1-4791-a60b-01ede91c8b5a
# 9         c3596048-eea7-4cdb-949c-ed052787476a
# 15        911fee96-3ae3-4284-ad20-b5fcfdbc9e48
# 16        c1125886-2b9d-421d-b821-920b6c5abb08
# 17        d90f6b9f-c874-4caf-b4bf-fd02af729687
# 20        eda61819-d669-4e08-be3a-b27c66069b5d
#
#                                   id_user_anon     trigger_event  \
# index_id
# 0         efddaabb-9a41-4cf1-b551-168a2d272198    hosting_update
# 1         7beba309-b7a9-4d06-b898-67a02c9042da  hosting_activate
# 2         5eea3e17-7496-4018-b3c3-4b38f8b160e8    hosting_update
# 5         d7ecffe3-ec4f-420d-90e2-eefe4360736e    hosting_update
# 6         68cce11c-57d1-4f5b-ac74-b361455c68e8    hosting_update
# ...

# %%
df_test_final.head(10)
# Out:
#           anon_feature_001  anon_feature_002  anon_feature_004  \
# index_id
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# 2                      NaN               NaN               NaN
# 5                      NaN               NaN               NaN
# 6                      NaN               NaN               NaN
# 9                      NaN               NaN               NaN
# 15                     NaN               NaN               NaN
# 16                     NaN               NaN               NaN
# 17                     NaN               NaN               NaN
# 20                0.939859           0.41684         -0.453761
#
#           anon_feature_005  anon_feature_006  anon_feature_008  \
# index_id
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# ...

# %%
df_test_final.to_csv('./data/test.csv',index=True)

# %%
df_test.to_csv('./data/test_with_original_columns.csv',index=True)

# %%
# %%bash
# head -n 5 ./data/test.csv
# Out:
# index_id,anon_feature_001,anon_feature_002,anon_feature_004,anon_feature_005,anon_feature_006,anon_feature_008,anon_feature_009,anon_feature_010,anon_feature_012,anon_feature_013,anon_feature_015,anon_feature_016,anon_feature_017,anon_feature_019,anon_feature_020,anon_feature_021,anon_feature_022,anon_feature_023,anon_feature_024,anon_feature_025,anon_feature_026,anon_feature_027,anon_feature_028,anon_feature_029,anon_feature_030,anon_feature_031,anon_feature_032,anon_feature_034,anon_feature_035,anon_feature_036,anon_feature_038,anon_feature_039,anon_feature_040,anon_feature_041,anon_feature_042,anon_feature_043,anon_feature_044,anon_feature_046,anon_feature_047,anon_feature_048,anon_feature_050,anon_feature_051,anon_feature_052,anon_feature_054,anon_feature_055,anon_feature_056,anon_feature_058,anon_feature_059,anon_feature_060,anon_feature_062,anon_feature_063,anon_feature_064,anon_feature_066,anon_feature_067,anon_feature_068,anon_feature_069,anon_feature_070,anon_feature_071,ano
# ...

# %%
# %%bash
# head -n 5 ./data/test_with_original_columns.csv
# Out:
# index_id,id_listing_anon,id_user_anon,trigger_event,ts,is_fi,fi_type,anon_feature_001,anon_feature_002,anon_feature_003,anon_feature_004,anon_feature_005,anon_feature_006,anon_feature_007,anon_feature_008,anon_feature_009,anon_feature_010,anon_feature_011,anon_feature_012,anon_feature_013,anon_feature_014,anon_feature_015,anon_feature_016,anon_feature_017,anon_feature_018,anon_feature_019,anon_feature_020,anon_feature_021,anon_feature_022,anon_feature_023,anon_feature_024,anon_feature_025,anon_feature_026,anon_feature_027,anon_feature_028,anon_feature_029,anon_feature_030,anon_feature_031,anon_feature_032,anon_feature_033,anon_feature_034,anon_feature_035,anon_feature_036,anon_feature_037,anon_feature_038,anon_feature_039,anon_feature_040,anon_feature_041,anon_feature_042,anon_feature_043,anon_feature_044,anon_feature_045,anon_feature_046,anon_feature_047,anon_feature_048,anon_feature_049,anon_feature_050,anon_feature_051,anon_feature_052,anon_feature_053,anon_feature_054,anon_featur
# ...

# %%
# !gsutil -m cp ./data/test.csv gs://airbnb_datasets
# Out:
# Updates are available for some Cloud SDK components.  To install them,
# please run:
#   $ gcloud components update
#
# Copying file://./data/test.csv [Content-Type=text/csv]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# - [1/1 files][  1.3 GiB/  1.3 GiB] 100% Done  43.2 MiB/s ETA 00:00:00
# Operation completed over 1 objects/1.3 GiB.
